# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Importing the dataset
dataset = pd.read_csv('/content/drive/MyDrive/Google Colab /ANN/Data Sets /Churn_Modelling.csv')
dataset
X = dataset.iloc[:, 3:13]
y = dataset.iloc[:, 13]

#Create dummy variables
geography=pd.get_dummies(X["Geography"],drop_first=True)
gender=pd.get_dummies(X['Gender'],drop_first=True)

## Concatenate the Data Frames

X=pd.concat([X,geography,gender],axis=1)

## Drop Unnecessary columns
X=X.drop(['Geography','Gender'],axis=1)

# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# Part 2 - Now let's make the ANN!

# Importing the Keras libraries and packages
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LeakyReLU,PReLU,ELU
from keras.layers import Dropout


# Initialising the ANN
classifier = Sequential()

# Adding the input layer and the first hidden layer
classifier.add(Dense(units= 6, kernel_initializer= 'he_uniform',activation='relu',input_dim = 11))

# Adding the second hidden layer
classifier.add(Dense(units= 6,kernel_initializer= 'he_uniform',activation='relu'))
# Adding the output layer
classifier.add(Dense(units= 1,kernel_initializer= 'glorot_uniform', activation = 'sigmoid'))

# Compiling the ANN
classifier.compile(optimizer = 'Adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# Fitting the ANN to the Training set
model_history=classifier.fit(X_train, y_train,validation_split=0.33, batch_size = 10, epochs= 100)

# list all data in history

print(model_history.history.keys())
# summarize history for accuracy
plt.plot(model_history.history['accuracy'])
plt.plot(model_history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# summarize history for loss
plt.plot(model_history.history['loss'])
plt.plot(model_history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# Part 3 - Making the predictions and evaluating the model

# Predicting the Test set results
y_pred = classifier.predict(X_test)
y_pred = (y_pred > 0.5)

# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
print(cm) 

# Calculate the Accuracy
from sklearn.metrics import accuracy_score
score=accuracy_score(y_pred,y_test)
score
# Out:
# Epoch 1/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.5083 - accuracy: 0.7809 - val_loss: 0.4618 - val_accuracy: 0.7970
# Epoch 2/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4494 - accuracy: 0.8016 - val_loss: 0.4429 - val_accuracy: 0.8012
# Epoch 3/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4344 - accuracy: 0.8087 - val_loss: 0.4380 - val_accuracy: 0.8031
# Epoch 4/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4291 - accuracy: 0.8149 - val_loss: 0.4369 - val_accuracy: 0.8023
# Epoch 5/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4252 - accuracy: 0.8162 - val_loss: 0.4329 - val_accuracy: 0.8069
# Epoch 6/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4218 - accuracy: 0.8166 - val_loss: 0.4303 - val_accuracy: 0.8073
# Epoch 7/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4189 - accuracy: 0.8209 - val_loss: 0.4303 - val_accuracy: 0.8058
# Epoch 8/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4164 - accuracy: 0.8224 - val_loss: 0.4274 - val_accuracy: 0.8073
# Epoch 9/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4130 - accuracy: 0.8250 - val_loss: 0.4249 - val_accuracy: 0.8065
# Epoch 10/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4098 - accuracy: 0.8246 - val_loss: 0.4226 - val_accuracy: 0.8080
# Epoch 11/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.4056 - accuracy: 0.8278 - val_loss: 0.4181 - val_accuracy: 0.8107
# Epoch 12/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3990 - accuracy: 0.8313 - val_loss: 0.4146 - val_accuracy: 0.8114
# Epoch 13/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3913 - accuracy: 0.8354 - val_loss: 0.4028 - val_accuracy: 0.8262
# Epoch 14/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3809 - accuracy: 0.8421 - val_loss: 0.3930 - val_accuracy: 0.8338
# Epoch 15/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3702 - accuracy: 0.8464 - val_loss: 0.3853 - val_accuracy: 0.8345
# Epoch 16/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3615 - accuracy: 0.8515 - val_loss: 0.3782 - val_accuracy: 0.8413
# Epoch 17/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3555 - accuracy: 0.8537 - val_loss: 0.3743 - val_accuracy: 0.8417
# Epoch 18/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3520 - accuracy: 0.8533 - val_loss: 0.3728 - val_accuracy: 0.8432
# Epoch 19/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3493 - accuracy: 0.8554 - val_loss: 0.3716 - val_accuracy: 0.8463
# Epoch 20/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3474 - accuracy: 0.8550 - val_loss: 0.3715 - val_accuracy: 0.8440
# Epoch 21/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3459 - accuracy: 0.8565 - val_loss: 0.3683 - val_accuracy: 0.8451
# Epoch 22/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3451 - accuracy: 0.8571 - val_loss: 0.3678 - val_accuracy: 0.8436
# Epoch 23/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3437 - accuracy: 0.8576 - val_loss: 0.3667 - val_accuracy: 0.8448
# Epoch 24/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3431 - accuracy: 0.8565 - val_loss: 0.3666 - val_accuracy: 0.8451
# Epoch 25/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3420 - accuracy: 0.8593 - val_loss: 0.3663 - val_accuracy: 0.8421
# Epoch 26/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3411 - accuracy: 0.8602 - val_loss: 0.3657 - val_accuracy: 0.8413
# Epoch 27/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3406 - accuracy: 0.8602 - val_loss: 0.3632 - val_accuracy: 0.8451
# Epoch 28/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3398 - accuracy: 0.8610 - val_loss: 0.3641 - val_accuracy: 0.8455
# Epoch 29/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3386 - accuracy: 0.8619 - val_loss: 0.3660 - val_accuracy: 0.8421
# Epoch 30/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3378 - accuracy: 0.8615 - val_loss: 0.3614 - val_accuracy: 0.8455
# Epoch 31/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3373 - accuracy: 0.8628 - val_loss: 0.3608 - val_accuracy: 0.8478
# Epoch 32/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3362 - accuracy: 0.8625 - val_loss: 0.3597 - val_accuracy: 0.8485
# Epoch 33/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3357 - accuracy: 0.8619 - val_loss: 0.3590 - val_accuracy: 0.8508
# Epoch 34/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3356 - accuracy: 0.8640 - val_loss: 0.3599 - val_accuracy: 0.8470
# Epoch 35/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3347 - accuracy: 0.8627 - val_loss: 0.3583 - val_accuracy: 0.8485
# Epoch 36/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3346 - accuracy: 0.8630 - val_loss: 0.3589 - val_accuracy: 0.8478
# Epoch 37/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3341 - accuracy: 0.8643 - val_loss: 0.3588 - val_accuracy: 0.8478
# Epoch 38/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3339 - accuracy: 0.8653 - val_loss: 0.3572 - val_accuracy: 0.8474
# Epoch 39/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3333 - accuracy: 0.8623 - val_loss: 0.3574 - val_accuracy: 0.8497
# Epoch 40/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3336 - accuracy: 0.8619 - val_loss: 0.3573 - val_accuracy: 0.8512
# Epoch 41/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3326 - accuracy: 0.8634 - val_loss: 0.3555 - val_accuracy: 0.8512
# Epoch 42/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3324 - accuracy: 0.8630 - val_loss: 0.3561 - val_accuracy: 0.8501
# Epoch 43/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3323 - accuracy: 0.8630 - val_loss: 0.3562 - val_accuracy: 0.8493
# Epoch 44/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3317 - accuracy: 0.8623 - val_loss: 0.3582 - val_accuracy: 0.8508
# Epoch 45/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3318 - accuracy: 0.8634 - val_loss: 0.3542 - val_accuracy: 0.8523
# Epoch 46/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3312 - accuracy: 0.8623 - val_loss: 0.3566 - val_accuracy: 0.8508
# Epoch 47/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3315 - accuracy: 0.8636 - val_loss: 0.3566 - val_accuracy: 0.8535
# Epoch 48/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3314 - accuracy: 0.8638 - val_loss: 0.3547 - val_accuracy: 0.8519
# Epoch 49/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3311 - accuracy: 0.8627 - val_loss: 0.3550 - val_accuracy: 0.8493
# Epoch 50/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3303 - accuracy: 0.8638 - val_loss: 0.3547 - val_accuracy: 0.8535
# Epoch 51/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3302 - accuracy: 0.8634 - val_loss: 0.3547 - val_accuracy: 0.8523
# Epoch 52/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3301 - accuracy: 0.8636 - val_loss: 0.3539 - val_accuracy: 0.8516
# Epoch 53/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3305 - accuracy: 0.8619 - val_loss: 0.3552 - val_accuracy: 0.8512
# Epoch 54/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3298 - accuracy: 0.8615 - val_loss: 0.3568 - val_accuracy: 0.8508
# Epoch 55/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3297 - accuracy: 0.8623 - val_loss: 0.3539 - val_accuracy: 0.8523
# Epoch 56/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3296 - accuracy: 0.8630 - val_loss: 0.3549 - val_accuracy: 0.8516
# Epoch 57/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3292 - accuracy: 0.8625 - val_loss: 0.3552 - val_accuracy: 0.8523
# Epoch 58/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3294 - accuracy: 0.8651 - val_loss: 0.3539 - val_accuracy: 0.8527
# Epoch 59/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3292 - accuracy: 0.8625 - val_loss: 0.3546 - val_accuracy: 0.8523
# Epoch 60/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3284 - accuracy: 0.8619 - val_loss: 0.3559 - val_accuracy: 0.8519
# Epoch 61/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3291 - accuracy: 0.8636 - val_loss: 0.3547 - val_accuracy: 0.8538
# Epoch 62/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3279 - accuracy: 0.8634 - val_loss: 0.3555 - val_accuracy: 0.8535
# Epoch 63/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3286 - accuracy: 0.8628 - val_loss: 0.3550 - val_accuracy: 0.8542
# Epoch 64/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3282 - accuracy: 0.8638 - val_loss: 0.3540 - val_accuracy: 0.8554
# Epoch 65/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3286 - accuracy: 0.8632 - val_loss: 0.3536 - val_accuracy: 0.8538
# Epoch 66/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3284 - accuracy: 0.8630 - val_loss: 0.3547 - val_accuracy: 0.8527
# Epoch 67/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3277 - accuracy: 0.8643 - val_loss: 0.3543 - val_accuracy: 0.8535
# Epoch 68/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3282 - accuracy: 0.8632 - val_loss: 0.3545 - val_accuracy: 0.8535
# Epoch 69/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3275 - accuracy: 0.8640 - val_loss: 0.3532 - val_accuracy: 0.8527
# Epoch 70/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3281 - accuracy: 0.8621 - val_loss: 0.3531 - val_accuracy: 0.8538
# Epoch 71/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3274 - accuracy: 0.8643 - val_loss: 0.3542 - val_accuracy: 0.8542
# Epoch 72/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3275 - accuracy: 0.8634 - val_loss: 0.3541 - val_accuracy: 0.8542
# Epoch 73/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3273 - accuracy: 0.8643 - val_loss: 0.3546 - val_accuracy: 0.8538
# Epoch 74/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3273 - accuracy: 0.8636 - val_loss: 0.3543 - val_accuracy: 0.8557
# Epoch 75/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3266 - accuracy: 0.8645 - val_loss: 0.3564 - val_accuracy: 0.8535
# Epoch 76/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3273 - accuracy: 0.8632 - val_loss: 0.3547 - val_accuracy: 0.8542
# Epoch 77/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3267 - accuracy: 0.8643 - val_loss: 0.3550 - val_accuracy: 0.8546
# Epoch 78/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3268 - accuracy: 0.8625 - val_loss: 0.3544 - val_accuracy: 0.8527
# Epoch 79/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3266 - accuracy: 0.8640 - val_loss: 0.3538 - val_accuracy: 0.8527
# Epoch 80/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3267 - accuracy: 0.8647 - val_loss: 0.3562 - val_accuracy: 0.8542
# Epoch 81/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3262 - accuracy: 0.8640 - val_loss: 0.3556 - val_accuracy: 0.8554
# Epoch 82/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3266 - accuracy: 0.8621 - val_loss: 0.3556 - val_accuracy: 0.8535
# Epoch 83/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3267 - accuracy: 0.8636 - val_loss: 0.3540 - val_accuracy: 0.8535
# Epoch 84/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3266 - accuracy: 0.8638 - val_loss: 0.3535 - val_accuracy: 0.8535
# Epoch 85/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3264 - accuracy: 0.8628 - val_loss: 0.3535 - val_accuracy: 0.8550
# Epoch 86/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3263 - accuracy: 0.8649 - val_loss: 0.3535 - val_accuracy: 0.8516
# Epoch 87/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3262 - accuracy: 0.8628 - val_loss: 0.3542 - val_accuracy: 0.8546
# Epoch 88/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3259 - accuracy: 0.8638 - val_loss: 0.3537 - val_accuracy: 0.8523
# Epoch 89/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3260 - accuracy: 0.8642 - val_loss: 0.3534 - val_accuracy: 0.8554
# Epoch 90/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3258 - accuracy: 0.8627 - val_loss: 0.3533 - val_accuracy: 0.8538
# Epoch 91/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3259 - accuracy: 0.8649 - val_loss: 0.3539 - val_accuracy: 0.8531
# Epoch 92/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3259 - accuracy: 0.8627 - val_loss: 0.3531 - val_accuracy: 0.8535
# Epoch 93/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3253 - accuracy: 0.8621 - val_loss: 0.3546 - val_accuracy: 0.8538
# Epoch 94/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3252 - accuracy: 0.8645 - val_loss: 0.3542 - val_accuracy: 0.8542
# Epoch 95/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3254 - accuracy: 0.8636 - val_loss: 0.3533 - val_accuracy: 0.8546
# Epoch 96/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3252 - accuracy: 0.8623 - val_loss: 0.3561 - val_accuracy: 0.8523
# Epoch 97/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3255 - accuracy: 0.8638 - val_loss: 0.3536 - val_accuracy: 0.8557
# Epoch 98/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3252 - accuracy: 0.8645 - val_loss: 0.3538 - val_accuracy: 0.8531
# Epoch 99/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3253 - accuracy: 0.8638 - val_loss: 0.3531 - val_accuracy: 0.8557
# Epoch 100/100
# 536/536 [==============================] - 1s 1ms/step - loss: 0.3253 - accuracy: 0.8640 - val_loss: 0.3547 - val_accuracy: 0.8531
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
# [[1497   98]
#  [ 194  211]]
# 0.854
